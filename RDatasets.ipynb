# %%
using RDatasets
using RCall

# %%
RDatasets.packages()
# Out:
# 33×2 DataFrame. Omitted printing of 1 columns
# │ Row │ Package      │
# │     │ String       │
# ├─────┼──────────────┤
# │ 1   │ COUNT        │
# │ 2   │ Ecdat        │
# │ 3   │ HSAUR        │
# │ 4   │ HistData     │
# │ 5   │ ISLR         │
# │ 6   │ KMsurv       │
# │ 7   │ MASS         │
# │ 8   │ SASmixed     │
# │ 9   │ Zelig        │
# │ 10  │ adehabitatLT │
# ⋮
# │ 23  │ plyr         │
# │ 24  │ pscl         │
# │ 25  │ psych        │
# │ 26  │ quantreg     │
# │ 27  │ reshape2     │
# │ 28  │ robustbase   │
# │ 29  │ rpart        │
# │ 30  │ sandwich     │
# │ 31  │ sem          │
# │ 32  │ survival     │
# │ 33  │ vcd          │

# %%
using Gadfly

# %%
iris = dataset("datasets", "iris")
# Out:
# 150×5 DataFrame
# │ Row │ SepalLength │ SepalWidth │ PetalLength │ PetalWidth │ Species      │
# │     │ Float64     │ Float64    │ Float64     │ Float64    │ Categorical… │
# ├─────┼─────────────┼────────────┼─────────────┼────────────┼──────────────┤
# │ 1   │ 5.1         │ 3.5        │ 1.4         │ 0.2        │ setosa       │
# │ 2   │ 4.9         │ 3.0        │ 1.4         │ 0.2        │ setosa       │
# │ 3   │ 4.7         │ 3.2        │ 1.3         │ 0.2        │ setosa       │
# │ 4   │ 4.6         │ 3.1        │ 1.5         │ 0.2        │ setosa       │
# │ 5   │ 5.0         │ 3.6        │ 1.4         │ 0.2        │ setosa       │
# │ 6   │ 5.4         │ 3.9        │ 1.7         │ 0.4        │ setosa       │
# │ 7   │ 4.6         │ 3.4        │ 1.4         │ 0.3        │ setosa       │
# │ 8   │ 5.0         │ 3.4        │ 1.5         │ 0.2        │ setosa       │
# │ 9   │ 4.4         │ 2.9        │ 1.4         │ 0.2        │ setosa       │
# ...

# %%
using DataFrames
summary(iris)
# Out:
# "150×5 DataFrame"

# %%
describe(iris)
# Out:
# 5×8 DataFrame. Omitted printing of 2 columns
# │ Row │ variable    │ mean    │ min    │ median │ max       │ nunique │
# │     │ Symbol      │ Union…  │ Any    │ Union… │ Any       │ Union…  │
# ├─────┼─────────────┼─────────┼────────┼────────┼───────────┼─────────┤
# │ 1   │ SepalLength │ 5.84333 │ 4.3    │ 5.8    │ 7.9       │         │
# │ 2   │ SepalWidth  │ 3.05733 │ 2.0    │ 3.0    │ 4.4       │         │
# │ 3   │ PetalLength │ 3.758   │ 1.0    │ 4.35   │ 6.9       │         │
# │ 4   │ PetalWidth  │ 1.19933 │ 0.1    │ 1.3    │ 2.5       │         │
# │ 5   │ Species     │         │ setosa │        │ virginica │ 3       │

# %%
head(iris)
# Out:
# ┌ Warning: `head(df::AbstractDataFrame)` is deprecated, use `first(df, 6)` instead.
# │   caller = top-level scope at In[10]:1
# └ @ Core In[10]:1
# 6×5 DataFrame
# │ Row │ SepalLength │ SepalWidth │ PetalLength │ PetalWidth │ Species      │
# │     │ Float64     │ Float64    │ Float64     │ Float64    │ Categorical… │
# ├─────┼─────────────┼────────────┼─────────────┼────────────┼──────────────┤
# │ 1   │ 5.1         │ 3.5        │ 1.4         │ 0.2        │ setosa       │
# │ 2   │ 4.9         │ 3.0        │ 1.4         │ 0.2        │ setosa       │
# │ 3   │ 4.7         │ 3.2        │ 1.3         │ 0.2        │ setosa       │
# │ 4   │ 4.6         │ 3.1        │ 1.5         │ 0.2        │ setosa       │
# │ 5   │ 5.0         │ 3.6        │ 1.4         │ 0.2        │ setosa       │
# │ 6   │ 5.4         │ 3.9        │ 1.7         │ 0.4        │ setosa       │

# %%
first(iris, 6)
# Out:
# 6×5 DataFrame
# │ Row │ SepalLength │ SepalWidth │ PetalLength │ PetalWidth │ Species      │
# │     │ Float64     │ Float64    │ Float64     │ Float64    │ Categorical… │
# ├─────┼─────────────┼────────────┼─────────────┼────────────┼──────────────┤
# │ 1   │ 5.1         │ 3.5        │ 1.4         │ 0.2        │ setosa       │
# │ 2   │ 4.9         │ 3.0        │ 1.4         │ 0.2        │ setosa       │
# │ 3   │ 4.7         │ 3.2        │ 1.3         │ 0.2        │ setosa       │
# │ 4   │ 4.6         │ 3.1        │ 1.5         │ 0.2        │ setosa       │
# │ 5   │ 5.0         │ 3.6        │ 1.4         │ 0.2        │ setosa       │
# │ 6   │ 5.4         │ 3.9        │ 1.7         │ 0.4        │ setosa       │

# %%
using Gadfly
plot(iris, x = "SepalWidth", y = "SepalLength", color="Species")
# Out:
# Plot(...)

# %%
using Clustering
# Out:
# ┌ Info: Precompiling Clustering [aaaa29a8-35af-508c-8bc3-b662a17a0fe5]
# └ @ Base loading.jl:1273

# %%
x = rand(100, 10000)
k = 50
result = kmeans(x, k; max_iter=50, display=:iter)
result.assignments
# Out:
# MethodError: no method matching kmeans(::Array{Float64,2}, ::Int64; max_iter=50, display=:iter)
# Closest candidates are:
#   kmeans(::AbstractArray{#s32,2} where #s32<:Real, ::Integer; weights, init, maxiter, tol, display, distance) at /Users/sugurumasui/.julia/packages/Clustering/fwZBk/src/kmeans.jl:103 got unsupported keyword argument "max_iter"
#
# Stacktrace:
#  [1] kwerr(::NamedTuple{(:max_iter, :display),Tuple{Int64,Symbol}}, ::Function, ::Array{Float64,2}, ::Int64) at ./error.jl:125
#  [2] (::Clustering.var"#kw##kmeans")(::NamedTuple{(:max_iter, :display),Tuple{Int64,Symbol}}, ::typeof(kmeans), ::Array{Float64,2}, ::Int64) at ./none:0
#  [3] top-level scope at In[16]:3

# %%
lm1 = lm(@formula(PetalWidth ~ PetalLength) , iris)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Array{Float64,1}},GLM.DensePredChol{Float64,LinearAlgebra.Cholesky{Float64,Array{Float64,2}}}},Array{Float64,2}}
#
# PetalWidth ~ 1 + PetalLength
#
# Coefficients:
# ─────────────────────────────────────────────────────────────────────────
#                  Coef.  Std. Error      t  Pr(>|t|)  Lower 95%  Upper 95%
# ─────────────────────────────────────────────────────────────────────────
# (Intercept)  -0.363076  0.039762    -9.13    <1e-15  -0.44165   -0.284501
# PetalLength   0.415755  0.00958244  43.39    <1e-85   0.396819   0.434691
# ─────────────────────────────────────────────────────────────────────────

# %%
using GLM
# Out:
# ┌ Info: Precompiling GLM [38e38edf-8417-5370-95a0-9cbb8c7f171a]
# └ @ Base loading.jl:1273

# %%
pre = predict(lm1)
plot!(iris[!, PetalLength],pre,label="predict")
# Out:
# UndefVarError: PetalLength not defined
#
# Stacktrace:
#  [1] top-level scope at In[23]:2

# %%
using Plots
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1273
# WARNING: using Plots.plot in module Main conflicts with an existing identifier.

# %%
plot!(iris[:PetalLength],pre,label="predict")
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[24]:1
# └ @ Core In[24]:1

# %%
housing = dataset("Ecdat", "Housing")
# Out:
# 546×12 DataFrame. Omitted printing of 6 columns
# │ Row │ Price  │ LotSize │ Bedrooms │ Bathrms │ Stories │ Driveway     │
# │     │ Int32  │ Int32   │ Int32    │ Int32   │ Int32   │ Categorical… │
# ├─────┼────────┼─────────┼──────────┼─────────┼─────────┼──────────────┤
# │ 1   │ 42000  │ 5850    │ 3        │ 1       │ 2       │ yes          │
# │ 2   │ 38500  │ 4000    │ 2        │ 1       │ 1       │ yes          │
# │ 3   │ 49500  │ 3060    │ 3        │ 1       │ 1       │ yes          │
# │ 4   │ 60500  │ 6650    │ 3        │ 1       │ 2       │ yes          │
# │ 5   │ 61000  │ 6360    │ 2        │ 1       │ 1       │ yes          │
# │ 6   │ 66000  │ 4160    │ 3        │ 1       │ 1       │ yes          │
# │ 7   │ 66000  │ 3880    │ 3        │ 2       │ 2       │ yes          │
# │ 8   │ 69000  │ 4160    │ 3        │ 1       │ 3       │ yes          │
# │ 9   │ 83800  │ 4800    │ 3        │ 1       │ 1       │ yes          │
# ...

# %%
plot(housing, x="LotSize", y="Price", Geom.point)
# Out:
# Plot(...)

# %%
log_housing = DataFrame(LotSize=log(housing[:,2]), Price=log(housing[:,1]))

plot(log_housing, x="LotSize", y="Price", Geom.pont, Guide.xlabel("LotSize(log)"), Guide.ylabel("Price(log)"))
# Out:
# MethodError: no method matching log(::Array{Int32,1})
# Closest candidates are:
#   log(!Matched::Float16) at math.jl:1085
#   log(!Matched::Complex{Float16}) at math.jl:1086
#   log(!Matched::Float64) at special/log.jl:254
#   ...
#
# Stacktrace:
#  [1] top-level scope at In[28]:1
